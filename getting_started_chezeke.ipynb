# %% [markdown]
# # Getting Started with Permuted MNIST Environment
#
# ## Objective
#
# The goal of this tutorial is to:
# - Learn how to use the PermutedMNIST environment for meta-learning experiments
# - Train and evaluate different agents on permuted MNIST tasks
# - Compare the performance of a **Random baseline** vs a **Linear classifier**
# - Achieve training and prediction in **less than 1 minute** per task
#
# ## What is Permuted MNIST?
#
# Permuted MNIST is a meta-learning benchmark where:
# - Each task uses the same MNIST dataset
# - For each task, pixels are randomly permuted (shuffled) in a consistent way
# - Labels are also randomly permuted (e.g., all 3s might become 7s)
# - The agent must quickly adapt to each new permutation

# %% [markdown]
# ## 1. Setup and Imports

# %%
# !git clone https://github.com/ml-arena/permuted_mnist.git
# %cd permuted_mnist
import sys
sys.path.append("/content/permuted_mnist")
# Out:
# Cloning into 'permuted_mnist'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 194 (delta 77), reused 163 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (194/194), 12.62 MiB | 6.09 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# /content/permuted_mnist

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from typing import Dict, List

# Import the environment and agents
from permuted_mnist.env.permuted_mnist import PermutedMNISTEnv
from permuted_mnist.agent.random.agent import Agent as RandomAgent
from permuted_mnist.agent.linear.agent import Agent as LinearAgent
from permuted_mnist.agent.torch_mlp.agent import Agent as MlpAgent

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# # Preparation

# %% [markdown]
# ## 2. Create the Environment
#
# Let's create an environment with 10 different permuted tasks:

# %%
# Create environment with 10 episodes (tasks)
env = PermutedMNISTEnv(number_episodes=10)

# Set seed for reproducibility
env.set_seed(42)

print(f"Environment created with {env.number_episodes} permuted tasks")
print(f"Training set size: {env.train_size} samples")
print(f"Test set size: {env.test_size} samples")
# Out:
# Environment created with 10 permuted tasks
# Training set size: 60000 samples
# Test set size: 10000 samples

# %% [markdown]
# ## 3. Understanding the Task Structure
#
# Let's examine what a single task looks like:

# %%
# Get the first task
task = env.get_next_task()

print("Task structure:")
print(f"- X_train shape: {task['X_train'].shape}")
print(f"- y_train shape: {task['y_train'].shape}")
print(f"- X_test shape: {task['X_test'].shape}")
print(f"- y_test shape: {task['y_test'].shape}")
print(f"\nLabel distribution in training set:")
unique, counts = np.unique(task['y_train'], return_counts=True)
for label, count in zip(unique, counts):
    print(f"  Label {label}: {count} samples")
# Out:
# Task structure:
# - X_train shape: (60000, 28, 28)
# - y_train shape: (60000, 1)
# - X_test shape: (10000, 28, 28)
# - y_test shape: (10000,)
#
# Label distribution in training set:
#   Label 0: 6131 samples
#   Label 1: 6742 samples
#   Label 2: 5421 samples
#   Label 3: 5851 samples
#   Label 4: 6265 samples
#   Label 5: 5958 samples
#   Label 6: 5949 samples
#   Label 7: 5842 samples
#   Label 8: 5923 samples
#   Label 9: 5918 samples

# %% [markdown]
# ## 4. Visualize Permuted Images
#
# Let's see how the permutation affects the images:

# %%
# Display some examples from the permuted task
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
fig.suptitle('Permuted MNIST Examples (Task 1)', fontsize=16)

for i in range(10):
    ax = axes[i // 5, i % 5]
    ax.imshow(task['X_train'][i], cmap='gray')
    ax.set_title(f'Label: {task["y_train"][i][0]}')
    ax.axis('off')

plt.tight_layout()
plt.show()

print("Note: The images look scrambled due to pixel permutation!")
print("The labels are also permuted (not the original MNIST labels).")
# Out:
# Note: The images look scrambled due to pixel permutation!
# The labels are also permuted (not the original MNIST labels).

# %% [markdown]
# ## 5. Baseline: Random Agent
#
# First, let's establish a baseline with an agent that makes random predictions:

# %%
# Reset environment for fresh start
env.reset()
env.set_seed(42)

# Create random agent
random_agent = RandomAgent(output_dim=10, seed=42)

# Track performance
random_accuracies = []
random_times = []

print("Evaluating Random Agent (Baseline)")
print("="*50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    start_time = time.time()

    # "Train" (random agent doesn't actually learn)
    random_agent.train(task['X_train'], task['y_train'])

    # Make predictions
    predictions = random_agent.predict(task['X_test'])

    # Calculate time and accuracy
    elapsed_time = time.time() - start_time
    accuracy = env.evaluate(predictions, task['y_test'])

    random_accuracies.append(accuracy)
    random_times.append(elapsed_time)

    print(f"Task {task_num}: Accuracy = {accuracy:.2%}, Time = {elapsed_time:.4f}s")
    task_num += 1

print(f"\nRandom Agent Summary:")
print(f"  Mean accuracy: {np.mean(random_accuracies):.2%} ± {np.std(random_accuracies):.2%}")
print(f"  Total time: {np.sum(random_times):.2f}s")
# Out:
# Evaluating Random Agent (Baseline)
# ==================================================
# Task 1: Accuracy = 9.96%, Time = 0.0005s
# Task 2: Accuracy = 9.70%, Time = 0.0003s
# Task 3: Accuracy = 10.41%, Time = 0.0003s
# Task 4: Accuracy = 10.02%, Time = 0.0003s
# Task 5: Accuracy = 10.23%, Time = 0.0003s
# Task 6: Accuracy = 9.94%, Time = 0.0003s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1117817612.py in <cell line: 0>()
#      16 task_num = 1
#      17 while True:
# ---> 18     task = env.get_next_task()
#      19     if task is None:
#      20         break
#
# /content/permuted_mnist/permuted_mnist/env/permuted_mnist.py in get_next_task(self)
#      68
#      69         # Apply pixel permutation and task-specific noise
# ---> 70         train_images = self._permute_pixels(train_images, self.current_episode)
#      71         test_images = self._permute_pixels(test_images, self.current_episode)
#      72
#
# /content/permuted_mnist/permuted_mnist/env/permuted_mnist.py in _permute_pixels(self, images, task_id)
#     100
#     101         # Add per-pixel Gaussian noise (std=0.015)
# --> 102         noise = task_rng.normal(0, 0.015, permuted_images.shape)
#     103         permuted_images = permuted_images + noise
#     104
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6. Linear Agent
#
# Now let's train a simple linear classifier that actually learns from the data:

# %%
# Reset environment
env.reset()
env.set_seed(42)

# Create linear agent
linear_agent = LinearAgent(input_dim=784, output_dim=10, learning_rate=0.01)

# Track performance
linear_accuracies = []
linear_times = []

print("Evaluating Linear Agent")
print("="*50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    # Reset agent for new task
    linear_agent.reset()

    start_time = time.time()

    # Train the linear model
    linear_agent.train(task['X_train'], task['y_train'], epochs=5, batch_size=32)

    # Make predictions
    predictions = linear_agent.predict(task['X_test'])

    # Calculate time and accuracy
    elapsed_time = time.time() - start_time
    accuracy = env.evaluate(predictions, task['y_test'])

    linear_accuracies.append(accuracy)
    linear_times.append(elapsed_time)

    print(f"Task {task_num}: Accuracy = {accuracy:.2%}, Time = {elapsed_time:.2f}s")
    task_num += 1

print(f"\nLinear Agent Summary:")
print(f"  Mean accuracy: {np.mean(linear_accuracies):.2%} ± {np.std(linear_accuracies):.2%}")
print(f"  Total time: {np.sum(linear_times):.2f}s")
# Out:
# Evaluating Linear Agent
# ==================================================
# Task 1: Accuracy = 90.82%, Time = 2.82s
# Task 2: Accuracy = 90.72%, Time = 3.93s
# Task 3: Accuracy = 90.88%, Time = 2.86s
# Task 4: Accuracy = 90.91%, Time = 3.79s
# Task 5: Accuracy = 90.94%, Time = 2.81s
# Task 6: Accuracy = 90.75%, Time = 3.47s
# Task 7: Accuracy = 90.72%, Time = 2.82s
# Task 8: Accuracy = 90.86%, Time = 3.25s
# Task 9: Accuracy = 90.83%, Time = 2.76s
# Task 10: Accuracy = 90.84%, Time = 2.80s
#
# Linear Agent Summary:
#   Mean accuracy: 90.83% ± 0.07%
#   Total time: 31.31s

# %% [markdown]
# ## 7. Performance Comparison
#
# Let's visualize and compare the performance of both agents:

# %%
# Create comparison plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy comparison
tasks = np.arange(1, len(random_accuracies) + 1)
ax1.plot(tasks, random_accuracies, 'o-', label='Random Agent', alpha=0.7, linewidth=2)
ax1.plot(tasks, linear_accuracies, 's-', label='Linear Agent', alpha=0.7, linewidth=2)
ax1.axhline(y=0.1, color='gray', linestyle='--', alpha=0.5, label='Random chance (10%)')
ax1.set_xlabel('Task Number')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy per Task')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylim([0, 1])

# Time comparison
ax2.bar(tasks - 0.2, random_times, 0.4, label='Random Agent', alpha=0.7)
ax2.bar(tasks + 0.2, linear_times, 0.4, label='Linear Agent', alpha=0.7)
ax2.axhline(y=60, color='red', linestyle='--', alpha=0.5, label='1 minute threshold')
ax2.set_xlabel('Task Number')
ax2.set_ylabel('Time (seconds)')
ax2.set_title('Training + Prediction Time per Task')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Statistical Comparison

# %%
# Create a summary comparison table
print("PERFORMANCE COMPARISON SUMMARY")
print("="*70)
print(f"{'Metric':<25} {'Random Agent':<20} {'Linear Agent':<20}")
print("-"*70)

# Accuracy metrics
print(f"{'Mean Accuracy':<25} {np.mean(random_accuracies):<20.2%} {np.mean(linear_accuracies):<20.2%}")
print(f"{'Std Accuracy':<25} {np.std(random_accuracies):<20.2%} {np.std(linear_accuracies):<20.2%}")
print(f"{'Min Accuracy':<25} {np.min(random_accuracies):<20.2%} {np.min(linear_accuracies):<20.2%}")
print(f"{'Max Accuracy':<25} {np.max(random_accuracies):<20.2%} {np.max(linear_accuracies):<20.2%}")

print("-"*70)

# Time metrics
print(f"{'Mean Time per Task':<25} {np.mean(random_times):<20.4f}s {np.mean(linear_times):<20.2f}s")
print(f"{'Total Time':<25} {np.sum(random_times):<20.4f}s {np.sum(linear_times):<20.2f}s")

print("="*70)

# Performance analysis
improvement = (np.mean(linear_accuracies) - np.mean(random_accuracies)) / np.mean(random_accuracies)
print(f"\n📊 Linear agent shows {improvement:.1%} improvement over random baseline")

# Check if objective is met
max_time_random = np.max(random_times)
max_time_linear = np.max(linear_times)

print(f"\n⏱️  Time Constraint Check (< 1 minute per task):")
print(f"   Random Agent: {'✅ PASS' if max_time_random < 60 else '❌ FAIL'} (max: {max_time_random:.2f}s)")
print(f"   Linear Agent: {'✅ PASS' if max_time_linear < 60 else '❌ FAIL'} (max: {max_time_linear:.2f}s)")
# Out:
# PERFORMANCE COMPARISON SUMMARY
# ======================================================================
# Metric                    Random Agent         Linear Agent
# ----------------------------------------------------------------------
# Mean Accuracy             10.08%               90.93%
# Std Accuracy              0.20%                0.08%
# Min Accuracy              9.70%                90.80%
# Max Accuracy              10.41%               91.07%
# ----------------------------------------------------------------------
# Mean Time per Task        0.0001              s 1.40                s
# Total Time                0.0013              s 13.97               s
# ======================================================================
#
# 📊 Linear agent shows 801.8% improvement over random baseline
#
# ⏱️  Time Constraint Check (< 1 minute per task):
#    Random Agent: ✅ PASS (max: 0.00s)
#    Linear Agent: ✅ PASS (max: 1.63s)

# %% [markdown]
# ## 9. Key Insights and Conclusions
#
# ### What we learned:
#
# 1. **Random Baseline**: The random agent achieves ~10% accuracy, which is expected for random guessing on 10 classes.
#
# 2. **Linear Agent Performance**: Despite the pixel and label permutations, the linear agent can learn patterns and achieve significantly better accuracy than random guessing.
#
# 3. **Time Efficiency**: Both agents meet the < 1 minute requirement, with the random agent being faster (no learning) and the linear agent still being very efficient.
#
# 4. **Meta-Learning Challenge**: Each task has different permutations, so the agent must learn from scratch each time. This tests the agent's ability to quickly adapt.
#
# ### Next Steps:
#
# - Try implementing more sophisticated agents (e.g., neural networks with better architectures)
# - Experiment with different hyperparameters (learning rate, epochs, batch size)
# - Implement meta-learning algorithms that can leverage experience from previous tasks
# - Add early stopping or adaptive learning rates for better performance

# %% [markdown]
# ## 10. Experiment: Tuning the Linear Agent
#
# Let's try different hyperparameters to see if we can improve performance:

# %%
# Test different learning rates
learning_rates = [0.001, 0.01, 0.1]
results = {}

for lr in learning_rates:
    # Reset environment
    env.reset()
    env.set_seed(42)

    # Create agent with different learning rate
    agent = LinearAgent(input_dim=784, output_dim=10, learning_rate=lr)

    accuracies = []

    # Run through tasks
    while True:
        task = env.get_next_task()
        if task is None:
            break

        agent.reset()
        agent.train(task['X_train'], task['y_train'], epochs=5, batch_size=32)
        predictions = agent.predict(task['X_test'])
        accuracy = env.evaluate(predictions, task['y_test'])
        accuracies.append(accuracy)

    results[lr] = np.mean(accuracies)
    print(f"Learning rate {lr}: Mean accuracy = {results[lr]:.2%}")

# Find best learning rate
best_lr = max(results, key=results.get)
print(f"\n🏆 Best learning rate: {best_lr} with {results[best_lr]:.2%} accuracy")
# Out:
# Learning rate 0.001: Mean accuracy = 86.21%
# Learning rate 0.01: Mean accuracy = 90.85%
# Learning rate 0.1: Mean accuracy = 92.13%
#
# 🏆 Best learning rate: 0.1 with 92.13% accuracy

# %% [markdown]
# # MLP Agents

# %% [markdown]
# ## Base Mlp

# %% [markdown]
# 1

# %%
# Reset environment
env.reset()
env.set_seed(42)

# Create linear agent
basemlp_agent = MlpAgent(output_dim=10, seed=42)

# Track performance
basemlp_accuracies = []
basemlp_times = []

print("Evaluating BaseMlp Agent")
print("="*50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    # Reset agent for new task
    basemlp_agent.reset()

    start_time = time.time()

    # Train the linear model
    basemlp_agent.train(task['X_train'], task['y_train'])

    # Make predictions
    predictions = basemlp_agent.predict(task['X_test'])

    # Calculate time and accuracy
    elapsed_time = time.time() - start_time
    accuracy = env.evaluate(predictions, task['y_test'])

    basemlp_accuracies.append(accuracy)
    basemlp_times.append(elapsed_time)

    print(f"Task {task_num}: Accuracy = {accuracy:.2%}, Time = {elapsed_time:.2f}s")
    task_num += 1

print(f"\nLinear Agent Summary:")
print(f"  Mean accuracy: {np.mean(basemlp_accuracies):.2%} ± {np.std(basemlp_accuracies):.2%}")
print(f"  Total time: {np.sum(basemlp_times):.2f}s")


# Reset environment for fresh start
env.reset()
env.set_seed(42)
# Out:
# Evaluating BaseMlp Agent
# ==================================================
# epoch 0: 0.9623%
# epoch 1: 0.9715%
# epoch 2: 0.9735%
# epoch 3: 0.9763%
# epoch 4: 0.9776%
# epoch 5: 0.9781%
# epoch 6: 0.9812%
# epoch 7: 0.9777%
# epoch 8: 0.9816%
# epoch 9: 0.9832%
# Task 1: Accuracy = 98.02%, Time = 174.16s
# epoch 0: 0.9636%
# epoch 1: 0.9732%
# epoch 2: 0.9742%
# epoch 3: 0.9779%
# epoch 4: 0.9813%
# epoch 5: 0.9793%
# epoch 6: 0.9802%
# epoch 7: 0.9817%
# epoch 8: 0.9801%
# epoch 9: 0.9817%
# Task 2: Accuracy = 98.18%, Time = 177.64s
# epoch 0: 0.9665%
# epoch 1: 0.9719%
# epoch 2: 0.9732%
# epoch 3: 0.9742%
# epoch 4: 0.9782%
# epoch 5: 0.9769%
# epoch 6: 0.9764%
# epoch 7: 0.9810%
# epoch 8: 0.9779%
# epoch 9: 0.9811%
# Task 3: Accuracy = 98.05%, Time = 168.06s
# epoch 0: 0.9617%
# epoch 1: 0.9732%
# epoch 2: 0.9751%
# epoch 3: 0.9774%
# epoch 4: 0.9782%
# epoch 5: 0.9773%
# epoch 6: 0.9821%
# epoch 7: 0.9829%
# epoch 8: 0.9834%
# epoch 9: 0.9806%
# Task 4: Accuracy = 98.07%, Time = 161.35s
# epoch 0: 0.9576%
# epoch 1: 0.9756%
# epoch 2: 0.9762%
# epoch 3: 0.9770%
# epoch 4: 0.9807%
# epoch 5: 0.9776%
# epoch 6: 0.9808%
# epoch 7: 0.9821%
# epoch 8: 0.9795%
# epoch 9: 0.9826%
# Task 5: Accuracy = 98.19%, Time = 159.87s
# epoch 0: 0.9618%
# epoch 1: 0.9712%
# epoch 2: 0.9748%
# epoch 3: 0.9753%
# epoch 4: 0.9750%
# epoch 5: 0.9770%
# epoch 6: 0.9792%
# epoch 7: 0.9798%
# epoch 8: 0.9800%
# epoch 9: 0.9808%
# Task 6: Accuracy = 98.21%, Time = 166.06s
# epoch 0: 0.9632%
# epoch 1: 0.9720%
# epoch 2: 0.9762%
# epoch 3: 0.9785%
# epoch 4: 0.9742%
# epoch 5: 0.9800%
# epoch 6: 0.9798%
# epoch 7: 0.9805%
# epoch 8: 0.9798%
# epoch 9: 0.9801%
# Task 7: Accuracy = 98.25%, Time = 165.01s
# epoch 0: 0.9632%
# epoch 1: 0.9710%
# epoch 2: 0.9738%
# epoch 3: 0.9762%
# epoch 4: 0.9777%
# epoch 5: 0.9808%
# epoch 6: 0.9770%
# epoch 7: 0.9803%
# epoch 8: 0.9781%
# epoch 9: 0.9823%
# Task 8: Accuracy = 98.11%, Time = 163.92s
# epoch 0: 0.9688%
# epoch 1: 0.9737%
# epoch 2: 0.9727%
# epoch 3: 0.9777%
# epoch 4: 0.9792%
# epoch 5: 0.9805%
# epoch 6: 0.9763%
# epoch 7: 0.9812%
# epoch 8: 0.9803%
# epoch 9: 0.9829%
# Task 9: Accuracy = 98.19%, Time = 166.76s
# epoch 0: 0.9595%
# epoch 1: 0.9734%
# epoch 2: 0.9733%
# epoch 3: 0.9765%
# epoch 4: 0.9817%
# epoch 5: 0.9795%
# epoch 6: 0.9791%
# epoch 7: 0.9825%
# epoch 8: 0.9822%
# epoch 9: 0.9838%
# Task 10: Accuracy = 98.11%, Time = 171.80s
#
# Linear Agent Summary:
#   Mean accuracy: 98.14% ± 0.07%
#   Total time: 1674.64s

# %% [markdown]
# standarized

# %%
# Reset environment
env.reset()
env.set_seed(42)

# Create linear agent
basemlp_agent = MlpAgent(output_dim=10, seed=42)

# Track performance
basemlp_accuracies = []
basemlp_times = []

print("Evaluating BaseMlp Agent")
print("="*50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    # Reset agent for new task
    basemlp_agent.reset()

    start_time = time.time()

    # Train the linear model
    basemlp_agent.train(task['X_train'], task['y_train'])

    # Make predictions
    predictions = basemlp_agent.predict(task['X_test'])

    # Calculate time and accuracy
    elapsed_time = time.time() - start_time
    accuracy = env.evaluate(predictions, task['y_test'])

    basemlp_accuracies.append(accuracy)
    basemlp_times.append(elapsed_time)

    print(f"Task {task_num}: Accuracy = {accuracy:.2%}, Time = {elapsed_time:.2f}s")
    task_num += 1

print(f"\nLinear Agent Summary:")
print(f"  Mean accuracy: {np.mean(basemlp_accuracies):.2%} ± {np.std(basemlp_accuracies):.2%}")
print(f"  Total time: {np.sum(basemlp_times):.2f}s")


# Reset environment for fresh start
env.reset()
env.set_seed(42)
# Out:
# Evaluating BaseMlp Agent
# ==================================================
# epoch 0: 0.9623%
# epoch 1: 0.9715%
# epoch 2: 0.9735%
# epoch 3: 0.9763%
# epoch 4: 0.9776%
# epoch 5: 0.9781%
# epoch 6: 0.9812%
# epoch 7: 0.9777%
# epoch 8: 0.9816%
# epoch 9: 0.9832%
# Task 1: Accuracy = 98.02%, Time = 163.56s
# epoch 0: 0.9636%
# epoch 1: 0.9732%
# epoch 2: 0.9742%
# epoch 3: 0.9779%
# epoch 4: 0.9813%
# epoch 5: 0.9793%
# epoch 6: 0.9802%
# epoch 7: 0.9817%
# epoch 8: 0.9801%
# epoch 9: 0.9817%
# Task 2: Accuracy = 98.18%, Time = 167.68s
# epoch 0: 0.9665%
# epoch 1: 0.9719%
# epoch 2: 0.9732%
# epoch 3: 0.9742%
# epoch 4: 0.9782%
# epoch 5: 0.9769%
# epoch 6: 0.9764%
# epoch 7: 0.9810%
# epoch 8: 0.9779%
# epoch 9: 0.9811%
# Task 3: Accuracy = 98.05%, Time = 170.43s
# epoch 0: 0.9617%
# epoch 1: 0.9732%
# epoch 2: 0.9751%
# epoch 3: 0.9774%
# epoch 4: 0.9782%
# epoch 5: 0.9773%
# epoch 6: 0.9821%
# epoch 7: 0.9829%
# epoch 8: 0.9834%
# epoch 9: 0.9806%
# Task 4: Accuracy = 98.07%, Time = 164.09s
# epoch 0: 0.9576%
# epoch 1: 0.9756%
# epoch 2: 0.9762%
# epoch 3: 0.9770%
# epoch 4: 0.9807%
# epoch 5: 0.9776%
# epoch 6: 0.9808%
# epoch 7: 0.9821%
# epoch 8: 0.9795%
# epoch 9: 0.9826%
# Task 5: Accuracy = 98.19%, Time = 164.74s
# epoch 0: 0.9618%
# epoch 1: 0.9712%
# epoch 2: 0.9748%
# epoch 3: 0.9753%
# epoch 4: 0.9750%
# epoch 5: 0.9770%
# epoch 6: 0.9792%
# epoch 7: 0.9798%
# epoch 8: 0.9800%
# epoch 9: 0.9808%
# Task 6: Accuracy = 98.21%, Time = 166.90s
# epoch 0: 0.9632%
# epoch 1: 0.9720%
# epoch 2: 0.9762%
# epoch 3: 0.9785%
# epoch 4: 0.9742%
# epoch 5: 0.9800%
# epoch 6: 0.9798%
# epoch 7: 0.9805%
# epoch 8: 0.9798%
# epoch 9: 0.9801%
# Task 7: Accuracy = 98.25%, Time = 163.52s
# epoch 0: 0.9632%
# epoch 1: 0.9710%
# epoch 2: 0.9738%
# epoch 3: 0.9762%
# epoch 4: 0.9777%
# epoch 5: 0.9808%
# epoch 6: 0.9770%
# epoch 7: 0.9803%
# epoch 8: 0.9781%
# epoch 9: 0.9823%
# Task 8: Accuracy = 98.11%, Time = 162.55s
# epoch 0: 0.9688%
# epoch 1: 0.9737%
# epoch 2: 0.9727%
# epoch 3: 0.9777%
# epoch 4: 0.9792%
# epoch 5: 0.9805%
# epoch 6: 0.9763%
# epoch 7: 0.9812%
# epoch 8: 0.9803%
# epoch 9: 0.9829%
# Task 9: Accuracy = 98.19%, Time = 165.57s
# epoch 0: 0.9595%
# epoch 1: 0.9734%
# epoch 2: 0.9733%
# epoch 3: 0.9765%
# epoch 4: 0.9817%
# epoch 5: 0.9795%
# epoch 6: 0.9791%
# epoch 7: 0.9825%
# epoch 8: 0.9822%
# epoch 9: 0.9838%
# Task 10: Accuracy = 98.11%, Time = 175.31s
#
# Linear Agent Summary:
#   Mean accuracy: 98.14% ± 0.07%
#   Total time: 1664.36s

# %% [markdown]
# # Others

# %% [markdown]
# ***MyAgent1***

# %%
# Reset environment for fresh start
env.reset()
env.set_seed(42)

# Create agent
my_agent = MyAgent1(output_dim=10, seed=42)

# Track performance
my_accuracies = []
my_times = []

print("Evaluating My Agent")
print("=" * 50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    X_tr, y_tr = task["X_train"], task["y_train"]
    X_te, y_te = task["X_test"], task["y_test"]

    start_time = time.time()

    # Train
    my_agent.train(X_tr, y_tr)

    # Predict
    preds = my_agent.predict(X_te)

    # Time & accuracy
    elapsed = time.time() - start_time
    acc = env.evaluate(preds, y_te)

    my_accuracies.append(acc)
    my_times.append(elapsed)

    print(f"Task {task_num}: Accuracy = {acc:.2%}, Time = {elapsed:.4f}s")
    task_num += 1

print("\nMY Agent1 Summary:")
print(f"  Mean accuracy: {np.mean(my_accuracies):.2%} ± {np.std(my_accuracies):.2%}")
print(f"  Total time: {np.sum(my_times):.2f}s")
# Out:
# Evaluating My Agent
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 1: Accuracy = 96.25%, Time = 18.3417s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 2: Accuracy = 96.14%, Time = 20.1865s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 3: Accuracy = 95.94%, Time = 21.1202s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 4: Accuracy = 96.08%, Time = 18.5715s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 5: Accuracy = 95.52%, Time = 18.6676s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 6: Accuracy = 95.07%, Time = 25.6561s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 7: Accuracy = 94.85%, Time = 29.2484s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 8: Accuracy = 94.86%, Time = 28.4417s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 9: Accuracy = 94.81%, Time = 34.8413s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 10: Accuracy = 94.88%, Time = 29.0190s
#
# MY Agent Summary:
#   Mean accuracy: 95.44% ± 0.58%
#   Total time: 244.09s

# %% [markdown]
# **MyAgent2**

# %%
# Reset environment for fresh start
env.reset()
env.set_seed(42)

# Create agent
my_agent = MyAgent2(output_dim=10, seed=42)

# Track performance
my_accuracies = []
my_times = []

print("Evaluating My Agent")
print("=" * 50)

# Evaluate on all tasks
task_num = 1
while True:
    task = env.get_next_task()
    if task is None:
        break

    X_tr, y_tr = task["X_train"], task["y_train"]
    X_te, y_te = task["X_test"], task["y_test"]

    start_time = time.time()

    # Train
    my_agent.train(X_tr, y_tr)

    # Predict
    preds = my_agent.predict(X_te)

    # Time & accuracy
    elapsed = time.time() - start_time
    acc = env.evaluate(preds, y_te)

    my_accuracies.append(acc)
    my_times.append(elapsed)

    print(f"Task {task_num}: Accuracy = {acc:.2%}, Time = {elapsed:.4f}s")
    task_num += 1

print("\nMY Agent2 Summary:")
print(f"  Mean accuracy: {np.mean(my_accuracies):.2%} ± {np.std(my_accuracies):.2%}")
print(f"  Total time: {np.sum(my_times):.2f}s")
# Out:
# Evaluating My Agent
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 1: Accuracy = 96.25%, Time = 20.0207s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 2: Accuracy = 96.17%, Time = 32.2282s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 3: Accuracy = 96.54%, Time = 31.3663s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 4: Accuracy = 96.32%, Time = 38.4475s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 5: Accuracy = 95.84%, Time = 48.9089s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 6: Accuracy = 95.82%, Time = 50.9947s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 7: Accuracy = 95.34%, Time = 52.3945s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 8: Accuracy = 95.50%, Time = 53.2145s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 9: Accuracy = 95.59%, Time = 52.4091s
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Task 10: Accuracy = 95.70%, Time = 53.2198s
#
# MY Agent2 Summary:
#   Mean accuracy: 95.91% ± 0.37%
#   Total time: 433.20s

# %% [markdown]
# Hyperparameters

# %%
# !python hpo_my_agent1.py
# Out:
# /usr/local/lib/python3.12/dist-packages/optuna/_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/optuna/_experimental.py:32: ExperimentalWarning: Argument ``constant_liar`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2025-11-11 00:08:21,481] A new study created in memory with name: permuted_mnist_hybrid_agent_hpo
#   0% 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:10:39,048] Trial 0 finished with value: 0.8791499999999999 and parameters: {'hidden0': 768, 'hidden1': 640, 'batch_size': 2048, 'epochs': 1, 'replay_max_samples': 8000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.2582458280396084, 'slope_replay_ratio': 0.14118528947223793, 'max_replay_ratio': 0.7278987721304083, 'learning_rate_init': 0.0019977251845629115, 'alpha': 0.00018033330377234335}. Best is trial 0 with value: 0.8791499999999999.
# Best trial: 0. Best value: 0.87915:   2% 1/50 [02:17<1:52:24, 137.64s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:12:42,265] Trial 1 finished with value: 0.81595 and parameters: {'hidden0': 768, 'hidden1': 512, 'batch_size': 4096, 'epochs': 1, 'replay_max_samples': 10000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.3818640804157564, 'slope_replay_ratio': 0.1058779981600017, 'max_replay_ratio': 0.8325044568707964, 'learning_rate_init': 0.0020364344296618215, 'alpha': 0.00023094679892576625}. Best is trial 0 with value: 0.8791499999999999.
# Best trial: 0. Best value: 0.87915:   4% 2/50 [04:20<1:43:19, 129.15s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:16:10,838] Trial 2 finished with value: 0.90906 and parameters: {'hidden0': 1024, 'hidden1': 256, 'batch_size': 2048, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.36043939615080794, 'slope_replay_ratio': 0.08745506436797708, 'max_replay_ratio': 0.8973773873201034, 'learning_rate_init': 0.0031992146836231504, 'alpha': 0.00013768806632111615}. Best is trial 2 with value: 0.90906.
# Best trial: 2. Best value: 0.90906:   6% 3/50 [07:49<2:09:35, 165.45s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:19:17,716] Trial 3 finished with value: 0.9324300000000001 and parameters: {'hidden0': 768, 'hidden1': 256, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.342648957444599, 'slope_replay_ratio': 0.15607850486168973, 'max_replay_ratio': 0.8122554395138992, 'learning_rate_init': 0.003195208268038473, 'alpha': 0.00022138506032035843}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:   8% 4/50 [10:56<2:13:18, 173.88s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:20:58,793] Trial 4 finished with value: 0.90488 and parameters: {'hidden0': 512, 'hidden1': 384, 'batch_size': 1024, 'epochs': 1, 'replay_max_samples': 10000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.3742921180375436, 'slope_replay_ratio': 0.16036720768991145, 'max_replay_ratio': 0.7373140117772071, 'learning_rate_init': 0.0035999252590299866, 'alpha': 0.00023822319727965374}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  10% 5/50 [12:37<1:50:43, 147.63s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:23:18,884] Trial 5 finished with value: 0.8746499999999999 and parameters: {'hidden0': 768, 'hidden1': 640, 'batch_size': 2048, 'epochs': 1, 'replay_max_samples': 10000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.3943564165441922, 'slope_replay_ratio': 0.1762447294942111, 'max_replay_ratio': 0.7503564591650728, 'learning_rate_init': 0.0024428881044366883, 'alpha': 0.00016229491527189777}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  12% 6/50 [14:57<1:46:22, 145.07s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:27:19,959] Trial 6 finished with value: 0.8764200000000001 and parameters: {'hidden0': 1024, 'hidden1': 512, 'batch_size': 4096, 'epochs': 2, 'replay_max_samples': 8000, 'replay_keep_tasks': 6, 'base_replay_ratio': 0.3071549368149517, 'slope_replay_ratio': 0.08902897700544082, 'max_replay_ratio': 0.8670604991178477, 'learning_rate_init': 0.0020546295819645175, 'alpha': 0.00013501152538227088}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  14% 7/50 [18:58<2:06:27, 176.45s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:31:28,055] Trial 7 finished with value: 0.88325 and parameters: {'hidden0': 1024, 'hidden1': 512, 'batch_size': 4096, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 6, 'base_replay_ratio': 0.3110401623198925, 'slope_replay_ratio': 0.13296505783560064, 'max_replay_ratio': 0.7483704581800903, 'learning_rate_init': 0.0016434258998488877, 'alpha': 0.0004237667739574106}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  16% 8/50 [23:06<2:19:28, 199.26s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:33:12,109] Trial 8 finished with value: 0.9093600000000002 and parameters: {'hidden0': 512, 'hidden1': 384, 'batch_size': 1024, 'epochs': 1, 'replay_max_samples': 12000, 'replay_keep_tasks': 6, 'base_replay_ratio': 0.33837903953853865, 'slope_replay_ratio': 0.14519612595026005, 'max_replay_ratio': 0.7448538618921119, 'learning_rate_init': 0.0030161805782937577, 'alpha': 0.0001464974265506749}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  18% 9/50 [24:50<1:55:49, 169.50s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:37:05,991] Trial 9 finished with value: 0.8737199999999999 and parameters: {'hidden0': 1280, 'hidden1': 256, 'batch_size': 4096, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.34449042305230104, 'slope_replay_ratio': 0.10807723624408558, 'max_replay_ratio': 0.7048631932862908, 'learning_rate_init': 0.002825154964947364, 'alpha': 0.00013298267121582917}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  20% 10/50 [28:44<2:06:15, 189.38s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:40:10,234] Trial 10 finished with value: 0.93076 and parameters: {'hidden0': 768, 'hidden1': 256, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.3492915945661547, 'slope_replay_ratio': 0.16537969084472223, 'max_replay_ratio': 0.8164130929507716, 'learning_rate_init': 0.002901780957643016, 'alpha': 0.0003688263621151038}. Best is trial 3 with value: 0.9324300000000001.
# Best trial: 3. Best value: 0.93243:  22% 11/50 [31:48<2:02:04, 187.80s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 00:43:10,354] Trial 11 finished with value: 0.9327400000000001 and parameters: {'hidden0': 768, 'hidden1': 256, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 8000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.3175009843655968, 'slope_replay_ratio': 0.1731164108425377, 'max_replay_ratio': 0.8164557005579266, 'learning_rate_init': 0.002687822728835476, 'alpha': 0.0004847221048382791}. Best is trial 11 with value: 0.9327400000000001.
# Best trial: 11. Best value: 0.93274:  24% 12/50 [34:48<1:57:27, 185.47s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 03:20:30,857] Trial 46 finished with value: 0.9192599999999999 and parameters: {'hidden0': 512, 'hidden1': 512, 'batch_size': 2048, 'epochs': 2, 'replay_max_samples': 8000, 'replay_keep_tasks': 6, 'base_replay_ratio': 0.31716152285369487, 'slope_replay_ratio': 0.1696127053725186, 'max_replay_ratio': 0.8833583839195809, 'learning_rate_init': 0.0018459540656090073, 'alpha': 0.0004472621870011545}. Best is trial 42 with value: 0.94664.
# Best trial: 42. Best value: 0.94664:  94% 47/50 [3:12:09<13:09, 263.04s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 03:23:22,916] Trial 47 finished with value: 0.9363100000000001 and parameters: {'hidden0': 512, 'hidden1': 512, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 8000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.3626246922434934, 'slope_replay_ratio': 0.13542468262786353, 'max_replay_ratio': 0.8735676997163935, 'learning_rate_init': 0.0016380962915803418, 'alpha': 0.0004458807849572237}. Best is trial 42 with value: 0.94664.
# Best trial: 42. Best value: 0.94664:  96% 48/50 [3:15:01<07:51, 235.75s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 03:28:23,018] Trial 48 finished with value: 0.9412800000000001 and parameters: {'hidden0': 1280, 'hidden1': 384, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 10000, 'replay_keep_tasks': 4, 'base_replay_ratio': 0.3682471888246662, 'slope_replay_ratio': 0.15228321576443316, 'max_replay_ratio': 0.8660059299990017, 'learning_rate_init': 0.0015406647175668592, 'alpha': 0.0003307982488775858}. Best is trial 42 with value: 0.94664.
# Best trial: 42. Best value: 0.94664:  98% 49/50 [3:20:01<04:15, 255.06s/it]/usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:609: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# [I 2025-11-11 03:33:28,673] Trial 49 finished with value: 0.9428699999999999 and parameters: {'hidden0': 1280, 'hidden1': 384, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 12000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.3932956793235074, 'slope_replay_ratio': 0.08956191201333641, 'max_replay_ratio': 0.8635388271162454, 'learning_rate_init': 0.0015272101363056764, 'alpha': 0.0003016412390705088}. Best is trial 42 with value: 0.94664.
# Best trial: 42. Best value: 0.94664: 100% 50/50 [3:25:07<00:00, 246.15s/it]
#
# [OPTUNA] best value (mean acc): 0.94664
# [OPTUNA] best params: {'hidden0': 1280, 'hidden1': 640, 'batch_size': 1024, 'epochs': 2, 'replay_max_samples': 12000, 'replay_keep_tasks': 5, 'base_replay_ratio': 0.36943093823537726, 'slope_replay_ratio': 0.08573207808680802, 'max_replay_ratio': 0.8867167597453343, 'learning_rate_init': 0.0015003265965406202, 'alpha': 0.0004783319229024152}
# [OPTUNA] user attrs: {'final_hidden': (1280, 640), 'batch_size': 1024, 'epochs': 2, 'replay_ratio_eval': 0.8867167597453343}
